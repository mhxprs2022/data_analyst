# %% [markdown]
# # Drawing Conclusions Using Groupby

# %% [markdown]
# Use `winequality_edited.csv`. You should've created this data file in the previous section: *Appending Data (cont.)*.

# %%
# Load dataset
import pandas as pd


df = pd.read_csv('winequality_edited.csv', sep=',')
df.head()
# Out:
#    alcohol  chlorides  citric_acid color  density  fixed_acidity  \
# 0      9.4      0.076         0.00   red   0.9978            7.4
# 1      9.8      0.098         0.00   red   0.9968            7.8
# 2      9.8      0.092         0.04   red   0.9970            7.8
# 3      9.8      0.075         0.56   red   0.9980           11.2
# 4      9.4      0.076         0.00   red   0.9978            7.4
#
#    free_sulfur_dioxide    pH  quality  residual_sugar  sulphates  \
# 0                 11.0  3.51        5             1.9       0.56
# 1                 25.0  3.20        5             2.6       0.68
# 2                 15.0  3.26        5             2.3       0.65
# 3                 17.0  3.16        6             1.9       0.58
# 4                 11.0  3.51        5             1.9       0.56
#
#    total_sulfur_dioxide  volatile_acidity   acidity_levels
# 0                  34.0              0.70              Low
# 1                  67.0              0.88  Moderately_High
# 2                  54.0              0.76           Medium
# 3                  60.0              0.28  Moderately_High
# 4                  34.0              0.70              Low

# %% [markdown]
# ### Is a certain type of wine associated with higher quality?

# %%
# Find the mean quality of each wine type (red and white) with groupby
df.groupby('color').mean().quality
# Out:
# color
# red      5.636023
# white    5.877909
# Name: quality, dtype: float64

# %% [markdown]
# ### What level of acidity receives the highest average rating?

# %%
# View the min, 25%, 50%, 75%, max pH values with Pandas describe
df.describe()
# Out:
#            alcohol    chlorides  citric_acid      density  fixed_acidity  \
# count  6497.000000  6497.000000  6497.000000  6497.000000    6497.000000
# mean     10.491801     0.056034     0.318633     0.994697       7.215307
# std       1.192712     0.035034     0.145318     0.002999       1.296434
# min       8.000000     0.009000     0.000000     0.987110       3.800000
# 25%       9.500000     0.038000     0.250000     0.992340       6.400000
# 50%      10.300000     0.047000     0.310000     0.994890       7.000000
# 75%      11.300000     0.065000     0.390000     0.996990       7.700000
# max      14.900000     0.611000     1.660000     1.038980      15.900000
#
#        free_sulfur_dioxide           pH      quality  residual_sugar  \
# count          6497.000000  6497.000000  6497.000000     6497.000000
# mean             30.525319     3.218501     5.818378        5.443235
# std              17.749400     0.160787     0.873255        4.757804
# min               1.000000     2.720000     3.000000        0.600000
# 25%              17.000000     3.110000     5.000000        1.800000
# 50%              29.000000     3.210000     6.000000        3.000000
# 75%              41.000000     3.320000     6.000000        8.100000
# max             289.000000     4.010000     9.000000       65.800000
#
#          sulphates  total_sulfur_dioxide  volatile_acidity
# count  6497.000000           6497.000000       6497.000000
# mean      0.531268            115.744574          0.339666
# std       0.148806             56.521855          0.164636
# min       0.220000              6.000000          0.080000
# 25%       0.430000             77.000000          0.230000
# 50%       0.510000            118.000000          0.290000
# 75%       0.600000            156.000000          0.400000
# max       2.000000            440.000000          1.580000

# %%
# Bin edges that will be used to "cut" the data into groups
bin_edges = [2.720000, 3.110000, 3.210000, 3.320000, 4.010000	] # Fill in this list with five values you just found

# %%
# Labels for the four acidity level groups
bin_names = [ 'High', 'Moderately_High', 'Medium', 'Low'] # Name each acidity level category

# %%
# Creates acidity_levels column
df['acidity_levels'] = pd.cut(df['pH'], bin_edges, labels=bin_names)

# Checks for successful creation of this column
df.head()
# Out:
#    alcohol  chlorides  citric_acid color  density  fixed_acidity  \
# 0      9.4      0.076         0.00   red   0.9978            7.4
# 1      9.8      0.098         0.00   red   0.9968            7.8
# 2      9.8      0.092         0.04   red   0.9970            7.8
# 3      9.8      0.075         0.56   red   0.9980           11.2
# 4      9.4      0.076         0.00   red   0.9978            7.4
#
#    free_sulfur_dioxide    pH  quality  residual_sugar  sulphates  \
# 0                 11.0  3.51        5             1.9       0.56
# 1                 25.0  3.20        5             2.6       0.68
# 2                 15.0  3.26        5             2.3       0.65
# 3                 17.0  3.16        6             1.9       0.58
# 4                 11.0  3.51        5             1.9       0.56
#
#    total_sulfur_dioxide  volatile_acidity   acidity_levels
# 0                  34.0              0.70              Low
# 1                  67.0              0.88  Moderately_High
# 2                  54.0              0.76           Medium
# 3                  60.0              0.28  Moderately_High
# 4                  34.0              0.70              Low

# %%
# Find the mean quality of each acidity level with groupby
df.groupby('acidity_levels').mean()
# Out:
#                    alcohol  chlorides  citric_acid   density  fixed_acidity  \
# acidity_levels
# High             10.330208   0.055131     0.370792  0.994708       7.543914
# Moderately_High  10.391073   0.054666     0.340548  0.994697       7.365064
# Medium           10.610369   0.055715     0.313585  0.994476       7.143566
# Low              10.656057   0.058777     0.243901  0.994899       6.769949
#
#                  free_sulfur_dioxide        pH   quality  residual_sugar  \
# acidity_levels
# High                       33.179965  3.029062  5.783343        7.088876
# Moderately_High            33.229154  3.164833  5.784540        5.931984
# Medium                     28.983995  3.267010  5.850832        4.721159
# Low                        26.327510  3.433348  5.859593        3.848983
#
#                  sulphates  total_sulfur_dioxide  volatile_acidity
# acidity_levels
# High              0.503937            129.897496          0.294683
# Moderately_High   0.509300            126.815886          0.318551
# Medium            0.541287            111.182138          0.346751
# Low               0.574136             93.244917          0.403815

# %%
# Save changes for the next section
df.to_csv('winequality_edited.csv', index=False)
